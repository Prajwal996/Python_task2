# %% [markdown]
#  ## Formated string

# %% [markdown]
# ####  Float example

# %%
a = 2.54
print(f"The type of a is {type(a)} and its value is '{a}'")

a = 2.54
print(f"The type of a is {type(a)} and its value is '{a}'")

a = 2.54
print(f"the type of a is {type(a)} and '{a}'")

a = 2.54
print(f"The type of a is {type(a)} and its value is '{a}'")

c = 3.655
print(f"the amount of c is {type(c)} that '{c}'")

ab =7.000
print(f" the challnge point of {type(ab)} is that '{ab}'")

oranges = 3.00
print(f" the cost of {type(oranges)} oranges is '{oranges}'")

monkey =8.6
print(f"there is the {type(monkey)} three monkey '{monkey}'")

pi = 3.14159
print(f"The value of pi is {type(pi)} and it is '{pi}'")

temperature = 37.5
print(f"The temperature recorded is {type(temperature)} and it is '{temperature}'")

height = 5.9
print(f"The height of the person is {type(height)} and it is '{height}'")

weight = 65.75
print(f"The weight of the object is {type(weight)} and it is '{weight}'")

speed = 88.6
print(f"The car's speed is {type(speed)} and it is '{speed}'")

length = 12.345
print(f"The measured length is {type(length)} and it is '{length}'")

radius = 7.5
print(f"The radius of the circle is {type(radius)} and it is '{radius}'")

distance = 102.33
print(f"The travel distance is {type(distance)} and it is '{distance}'")

density = 1.225
print(f"The air density is {type(density)} and it is '{density}'")

price = 250.00
print(f"The product price is {type(price)} and it is '{price}'")

bmi = 23.45
print(f"The calculated BMI is {type(bmi)} and it is '{bmi}'")

interest_rate = 6.75
print(f"The interest rate is {type(interest_rate)} and it is '{interest_rate}'")

fuel_price = 104.58
print(f"The fuel price is {type(fuel_price)} and it is '{fuel_price}'")

exchange_rate = 83.25
print(f"The USD to INR exchange rate is {type(exchange_rate)} and it is '{exchange_rate}'")

gravity = 9.81
print(f"The gravitational acceleration is {type(gravity)} and it is '{gravity}'")

lat = 19.076
print(f"The latitude coordinate is {type(lat)} and it is '{lat}'")

long = 72.8777
print(f"The longitude coordinate is {type(long)} and it is '{long}'")

score = 89.95
print(f"The student score is {type(score)} and it is '{score}'")
# Out:
# The type of a is <class 'float'> and its value is '2.54'
# The type of a is <class 'float'> and its value is '2.54'
# the type of a is <class 'float'> and '2.54'
# The type of a is <class 'float'> and its value is '2.54'
# the amount of c is <class 'float'> that '3.655'
#  the challnge point of <class 'float'> is that '7.0'
#  the cost of <class 'float'> oranges is '3.0'
# there is the <class 'float'> three monkey '8.6'
# The value of pi is <class 'float'> and it is '3.14159'
# The temperature recorded is <class 'float'> and it is '37.5'
# The height of the person is <class 'float'> and it is '5.9'
# The weight of the object is <class 'float'> and it is '65.75'
# The car's speed is <class 'float'> and it is '88.6'
# The measured length is <class 'float'> and it is '12.345'
# The radius of the circle is <class 'float'> and it is '7.5'
# The travel distance is <class 'float'> and it is '102.33'
# The air density is <class 'float'> and it is '1.225'
# ...

# %% [markdown]
# #### String examples

# %%
call = "akash"
print(f"the name of artist {type(call)} is '{call}'")

name = "akshay"
print(f" the college boy is {type(name)} '{name}'")

place = "nagpur"
print(f" the name of place {type(place)} is '{place}'")

subtance ="liquid"
print(f" there is a {type(subtance)} what type of subtance'{subtance}'")

gender ="female"
print(f" which gender is {type(gender)} present there {gender}")

caste = "obc"
print(f" the cast of the person is {type(caste)} that{caste}")

language = "Python"
print(f"The programming language used is {type(language)} and it is '{language}'")

vehicle = "car"
print(f"The vehicle type is {type(vehicle)} and it is '{vehicle}'")

country = "India"
print(f"The country name is {type(country)} and it is '{country}'")

fruit = "mango"
print(f"The favorite fruit is {type(fruit)} and it is '{fruit}'")

color = "blue"
print(f"The selected color is {type(color)} and it is '{color}'")

emotion = "happy"
print(f"The current emotion is {type(emotion)} and it is '{emotion}'")

subject = "mathematics"
print(f"The subject of interest is {type(subject)} and it is '{subject}'")

season = "winter"
print(f"The season going on is {type(season)} and it is '{season}'")

brand = "Nike"
print(f"The brand name is {type(brand)} and it is '{brand}'")

browser = "Chrome"
print(f"The web browser in use is {type(browser)} and it is '{browser}'")
# Out:
# the name of artist <class 'str'> is 'akash'
#  the college boy is <class 'str'> 'akshay'
#  the name of place <class 'str'> is 'nagpur'
#  there is a <class 'str'> what type of subtance'liquid'
#  which gender is <class 'str'> present there female
#  the cast of the person is <class 'str'> thatobc
# The programming language used is <class 'str'> and it is 'Python'
# The vehicle type is <class 'str'> and it is 'car'
# The country name is <class 'str'> and it is 'India'
# The favorite fruit is <class 'str'> and it is 'mango'
# The selected color is <class 'str'> and it is 'blue'
# The current emotion is <class 'str'> and it is 'happy'
# The subject of interest is <class 'str'> and it is 'mathematics'
# The season going on is <class 'str'> and it is 'winter'
# The brand name is <class 'str'> and it is 'Nike'
# The web browser in use is <class 'str'> and it is 'Chrome'

# %% [markdown]
# #### Intt Example

# %%
num = 42
print(f"type of num is {type(num)} and value is '{num}'")

num =54 
print(f"type of num is {type(num)} and value is '{num}'")

num =67
print(f"type of num is {type(num)} and value is '{num}'")


number=70 
print(f"type of number is {type(number)} and value is '{num}'")

P =1 
print(f"type of P is {type(P)} and Value of P is '{P}'")

Price = 4169 
print(f"type of Price is {type(Price)} and cost of price is '{Price}'")
 
 
umbrella = 255
print(f"type of umbrella is {type(umbrella)} and price of umbrella is '{umbrella}'")

umbrella = 255
print(f"type of umbrella is {type(umbrella)} and price of umbrella is '{umbrella}'")

age =25
print(f" age of boy {type(age)} rakesh is '{age}'")

age = 50
print(f" age of older person {type(age)} is '{age}'")

rs = 1000
print(f" Clothe price from Shop {type(rs)} is '{rs}'")

ms = 944
print(f" Price of Cycle {type(ms)} is'{ms}'")

america = 8 
print(f" Position of america is {type(america)} now '{america}'")

india =5 
print(f" Position of india is {type(india)} now '{india}'")

collection = 46982
print(f" Collected amount of bank {type(collection)} Saraswat is '{collection}'")

fees = 1200 
print(f" school fees of college {type(fees)} js is '{fees}'")
# Out:
# type of num is <class 'int'> and value is '42'
# type of num is <class 'int'> and value is '54'
# type of num is <class 'int'> and value is '67'
# type of number is <class 'int'> and value is '67'
# type of P is <class 'int'> and Value of P is '1'
# type of Price is <class 'int'> and cost of price is '4169'
# type of umbrella is <class 'int'> and price of umbrella is '255'
# type of umbrella is <class 'int'> and price of umbrella is '255'
#  age of boy <class 'int'> rakesh is '25'
#  age of older person <class 'int'> is '50'
#  Clothe price from Shop <class 'int'> is '1000'
#  Price of Cycle <class 'int'> is'944'
#  Position of america is <class 'int'> now '8'
#  Position of india is <class 'int'> now '5'
#  Collected amount of bank <class 'int'> Saraswat is '46982'
#  school fees of college <class 'int'> js is '1200'

# %% [markdown]
# #### Boolean Example

# %%
bol1 = True
print(f"type of bol1 is {type(bol1)} and value is '{bol1}'")

bol2 = False
print(f"type of bol2 is {type(bol2)} and value is '{bol2}'")

is_logged_in = True
print(f"type of is_logged_in is {type(is_logged_in)} and value is '{is_logged_in}'")

is_admin = False
print(f"type of is_admin is {type(is_admin)} and value is '{is_admin}'")

has_permission = True
print(f"type of has_permission is {type(has_permission)} and value is '{has_permission}'")

is_day = False
print(f"type of is_day is {type(is_day)} and value is '{is_day}'")

lights_on = True
print(f"type of lights_on is {type(lights_on)} and value is '{lights_on}'")

exam_passed = False
print(f"type of exam_passed is {type(exam_passed)} and value is '{exam_passed}'")

is_hungry = True
print(f"type of is_hungry is {type(is_hungry)} and value is '{is_hungry}'")

has_internet = False
print(f"type of has_internet is {type(has_internet)} and value is '{has_internet}'")
# Out:
# type of bol1 is <class 'bool'> and value is 'True'
# type of bol2 is <class 'bool'> and value is 'False'
# type of is_logged_in is <class 'bool'> and value is 'True'
# type of is_admin is <class 'bool'> and value is 'False'
# type of has_permission is <class 'bool'> and value is 'True'
# type of is_day is <class 'bool'> and value is 'False'
# type of lights_on is <class 'bool'> and value is 'True'
# type of exam_passed is <class 'bool'> and value is 'False'
# type of is_hungry is <class 'bool'> and value is 'True'
# type of has_internet is <class 'bool'> and value is 'False'
